# %% [markdown]
# <a href="https://colab.research.google.com/github/duchaba/book_python_genAI_genZ/blob/master/Chapter_1_Ashley_Python_GenAI_GenZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌻 Welcome Reader and Coder
# ---
#
# - Let's Rock and Roll

# %%
fname = 'Ellie Belly'
print(f'Welcome reader and coder: {fname}.')
# Out:
# Welcome reader and coder: Ellie Belly.

# %% [markdown]
# # 📗 Book Title – Python Simplified with Generative AI
#
#
# ---
#
# ## Introduction:
#
# In the bustling corridors of the university, amidst the chatter of new ideas and the rustle of
# textbooks, there is a common thread of a challenge looming before us. As college students, we
# faced the daunting task of navigating the digital landscape, such as learning about complex
# programming code, internalizing AI paradigms, and expanding our personal growth.
#
# However, most existing books fail to connect with us. The books seem distant because they
# were authored by academics and industry professionals who disconnected from the
# challenges of the new Generative Artificial Intelligence (GenAI) era in education. Hence, we
# propose to craft this book, written by college students for college students, with a coauthor
# who is a renowned AI leader and an author of the book “Data Augmentation with Python.”
#
# We are a generation that thrives on immediacy and experiential learning. The GenZ, our lot,
# don’t just learn; we ‘do,’ we ‘experience.’ And that’s where GenAI, such as GPT-4’s Copilot,
# Meta Code Llama, or Google Gemini, emerges as a beacon. Drawing inspiration from the
# growth of AI in modern learning, GenAI is your personalized coach or a teaching assistant
# always by your side.
#
# The proposed book's core learning experience will be a narrative of a human and an AI
# working together to learn from a series of short, interactive projects on Python Jupyter
# Notebooks (Notebooks). Along the way, the reader will learn how to write code in Python and
# practice it on a copy of the Notebook. The lessons are functional projects recognizable to
# GenZ as everyday activities.
#
# In contrast, many Python books prioritize comprehending data structures, algorithms, and
# complex syntax before implementing them. Furthermore, the outdated teaching approach
# relies solely on one narrative and doesn't allow students to independently investigate and
# challenge the lessons.
#
# The play-first method increases confidence and connects theory, GenAI, and real-world
# application. It aligns with GenZ's preference for experiential learning, i.e., learning by doing.
# The readers will remember that this isn’t just another Python book. Instead, it is a unique
# journey where a fellow human and digital GenAI will accompany you every step. They will
# teach, demonstrate, guide, assist, and motivate as you learn Python coding. Furthermore, the
# readers can adapt the learning journey to various other college topics, including but not
# limited to science, history, art, and communication. Welcome to a learning experience
# tailored for our generation by one of our own.

# %% [markdown]
# # 🍎 Welcome to Chapter 1: Introduction to GenAI and Prompt Engineering
# ---

# %% [markdown]
# ## 🐳 Author: Ashley
# ---
# ## Description:
#
# Embark on an enlightening journey into the realm of Generative Artificial Intelligence
# (GenAI) with the guidance of Chat GPT-4 and Google Gemini. This chapter is designed for
# curious minds eager to delve into the innovative landscape of AI, where creating new,
# dynamic content is at the forefront. Whether you're a beginner in AI or a seasoned
# professional looking to expand your knowledge, this chapter offers a friendly yet insightful
# pathway to understanding and utilizing the power of GenAI.
#
# GenAI is a remarkable advancement in AI, offering unparalleled capabilities in generating
# diverse content, from text to images. Chat GPT-4, a sophisticated language model from
# OpenAI, is a prime example of GenAI's capabilities. Google Gemini, which we will assume to
# be a complementary AI platform, enhances these capabilities further. Together, they open up
# possibilities in AI-driven creativity and innovation.
# This chapter will explore the intricacies of setting up and harnessing the power of GPT-4 and
# Google Gemini. You'll learn how to seamlessly integrate these advanced tools and configure
# them to suit your needs, whether in data analysis, content creation, or problem-solving.
#
# Moreover, we'll dive into the art and science of Prompt Engineering. This involves crafting
# prompts in a way that effectively guides AI to produce the most accurate, relevant, and
# creative outputs. Understanding Prompt Engineering is vital to maximizing the potential of
# GenAI tools like GPT-4 and Gemini.
#
# So, let's begin this exciting adventure. As you turn these pages, you'll gain knowledge and
# practical skills in navigating and leveraging the dynamic capabilities of GenAI with Chat
# GPT-4 and Google Gemini. This chapter promises to be a gateway to mastering AI
# technologies and their applications in the real world. Welcome to the future of AI!
#
# ## Introduction:
# First and foremost, I will approach Chapter 1 as a storytelling journey, not a mere collection
# of facts and instructions. In other words, I will narrate my journey of discovering GenAI in a
# conversational tone, sharing how I learned to use it effectively rather than providing a
# comprehensive list of AI-related information in a bullet-point format.
#
# I plan to use OpenAI GPT-4 and Google Genimi as research assistants. At times, I will
# directly display and label the answer provided by GenAI. On other occasions, I will
# summarize and provide my own opinions on the researched material from GenAI.
#
# ---
#
# ## Topics to be covered:
# 1. What is GenAI?
#
# 2. Accessing Gemini and GPT-4
# 2. What is Python?
# 3. GenAI Limitation
# 4. Prompt Engineering
# 5. Accessing GenAI on Laptop, iPad, and iPhone

# %% [markdown]
# # 🤖 Topic #1: What is GenAI?
#
# ---
#
# - Login GPT-4, https://chat.openai.com/
#
# - Open a "new chat" session
#
# - Start by asking "What is GenAI" from GPT-4. Here are some sample prompts to help you get started, but **highly encourage** you to write your prompts to express your idea of fun.
#
#   1. What is GenAI?
#
#   2. Explain GenAI to a five year old kid.
#     - Expand the above with more details and examples.
#
#   3. Write about GenAI from a college student point of view.
#
#   4. Write a story about GenAI from a aspired writer point of view in a conversational tone.
#
#   5. Why should a programmer want to learn about GenAI?
#
#   6. How would a micro biologist use GenAI?
#
#   7. How can a college proffesor use GenAI for his class?
#
#   8. If I am a famous Blackbeard pirates, how would I use GenAI to plunder more gold?
#
#   9. *(Your fun prompts goes here.)*

# %%
# prompt: What is GenAI?

# %% [markdown]
# ## Suggestion on the writing process
#
# ---
#
# - After you read all the answer from GPT-4 above:
#
#   - write about why you ask this question,
#
#   - what you exspect to read,
#   - how you feel about the answer
#   - summarize GPT-4 highlight/good point
#     - quote GPT-4 if you want to
#   - what surprise you about the answer.

# %% [markdown]
# # 🤖 Topic #2: Accessing Gemini and GPT-4
#
# ---
#
# - Write about step-by-step on how do you access GPT-4.
#
# - Add screen shot images so to help the readers.

# %%
print ("staring topic 2 of chapter 1.")
# Out:
# staring topic 2 of chapter 1.

# %% [markdown]
# # 🤖 Topic #3: What is Python?
#
# ---
#
# - Start by asking "What is Python" from GPT-4. Here are some sample prompts to help you get started, but **highly encourage** you to write your prompts to express your idea of fun.
#
#   1. Explain Python language in a compact format for a book introduction.
#
#   2. If I am a middle school student, why should I want to know about Python lanague.
#
#   3. Write ten slogun for the Python language.
#
#   4. *(Your fun prompts goes here.)*

# %% [markdown]
# #### 🐣 Fun Fact:
# ---
# The below code is written entirely by GenAI with just the prompt:

# %%
# prompt: write one line code to estimate the value of pi

import math
print(math.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# # 🤖 Topic #4: GenAI Limitation
#
# ---
#
# - Start by asking "What is GenAI Limitation" from GPT-4. Here are some sample prompts to help you get started, but **highly encourage** you to write your prompts to express your idea of fun.
#
#   1. Write the top 10 GenAI limitation in a bullet list format.
#
#   2. If I am using GenAI to write a business proposal for my company's use of GenAI in marketing, what are the major issues?
#
#   3. If I am writing a college history term paper on World World 1 using GenAI, is that cheating?
#
#   4. *(Your prompt goes here.)*

# %% [markdown]
# #### 🐣 Fun Fact:
# ---
# The below code is written entirely by GenAI with just the prompt:

# %%
# prompt: draw last month average temperature in USA.

import pandas as pd
import matplotlib.pyplot as plt

# Create a dataframe with the average temperature for each state in the USA
df = pd.DataFrame({
    'state': ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia'],
    'avg_temp': [68.4, 32.2, 73.8, 63.5, 59.3, 49.1, 52.7, 55.3, 72.8, 66.9]
})

# Plot the average temperature for each state
df.plot.bar(x='state', y='avg_temp')
plt.xlabel('State')
plt.ylabel('Average Temperature (°F)')
plt.title('Average Temperature in the USA Last Month')
plt.show()

# %% [markdown]
# # 🤖 Topic #5: Prompt Engineering
#
# ---
#
# - Start by asking "What is Prompt Engineering" from GPT-4. Here are some sample prompts to help you get started, but **highly encourage** you to write your prompts to express your idea of fun.
#
#   1. Explain prompt engineering as a sales brochure.
#
#   2. Give 5 examples of prompt engineering for creating a picture of a man on a bicyle in the Renaissance style.
#     - Copy and past the given prompts above and see the image.
#
#   3. Create a style guide for prompt engineering for different topics or scenarios.
#
#   4. *(Your prompt goes here.)*

# %% [markdown]
# #### 🐣 Fun Fact:
# ---
# The below code is written entirely by GenAI with just the prompt:

# %%
# prompt: draw a 3-d graph of z = x * exp(-(x^2 + y^2))

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a grid of x and y values
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)

# Calculate z values
z = X * np.exp(-(X**2 + Y**2))

# Create a 3D plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(X, Y, z, cmap='viridis')

# Set labels and title
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Surface Plot of z = x * exp(-(x^2 + y^2))')

# Show the plot
plt.show()

# %% [markdown]
# # 🤖 Topic #6: Accessing GenAI on Laptop, iPad, and iPhone
#
# - Last topic then Conclusion
#
# ---
#
# - Start by typing https://chat.openai.com to the browser on the iPad and iPhone.
#
# - Copy the screenshots.
#
# - Download the OpenAI Chat app, and show how that work with screenshots too.

# %% [markdown]
# # 🍵 Conclusion
#
# ---
#
# - Summarize what we have done in this chapter.
#
# - Write your thoughts about chapter 1.
#
# - Memtion the next chapter, chapter 2 is about Jupyter Notebook, and the author is Evan.

# %%
print("end of chapter 1.")
# Out:
# end of chapter 1.
