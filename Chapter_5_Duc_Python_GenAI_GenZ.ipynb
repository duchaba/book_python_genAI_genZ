# %% [markdown]
# <a href="https://colab.research.google.com/github/duchaba/book_python_genAI_genZ/blob/master/Chapter_5_Duc_Python_GenAI_GenZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌻 Welcome Reader and Coder
# ---
#
# - Let's Rock and Roll

# %%
fname = 'Monty'
print(f'Welcome reader and coder: {fname}.')
# Out:
# Welcome reader and coder: Monty.

# %% [markdown]
# # 📗 Book Title – Python Simplified with Generative AI
#
#
# ---
#
# ## Introduction:
#
# In the bustling corridors of the university, amidst the chatter of new ideas and the rustle of
# textbooks, there is a common thread of a challenge looming before us. As college students, we
# faced the daunting task of navigating the digital landscape, such as learning about complex
# programming code, internalizing AI paradigms, and expanding our personal growth.
#
# However, most existing books fail to connect with us. The books seem distant because they
# were authored by academics and industry professionals who disconnected from the
# challenges of the new Generative Artificial Intelligence (GenAI) era in education. Hence, we
# propose to craft this book, written by college students for college students, with a coauthor
# who is a renowned AI leader and an author of the book “Data Augmentation with Python.”
#
# We are a generation that thrives on immediacy and experiential learning. The GenZ, our lot,
# don’t just learn; we ‘do,’ we ‘experience.’ And that’s where GenAI, such as GPT-4’s Copilot,
# Meta Code Llama, or Google Gemini, emerges as a beacon. Drawing inspiration from the
# growth of AI in modern learning, GenAI is your personalized coach or a teaching assistant
# always by your side.
#
# The proposed book's core learning experience will be a narrative of a human and an AI
# working together to learn from a series of short, interactive projects on Python Jupyter
# Notebooks (Notebooks). Along the way, the reader will learn how to write code in Python and
# practice it on a copy of the Notebook. The lessons are functional projects recognizable to
# GenZ as everyday activities.
#
# In contrast, many Python books prioritize comprehending data structures, algorithms, and
# complex syntax before implementing them. Furthermore, the outdated teaching approach
# relies solely on one narrative and doesn't allow students to independently investigate and
# challenge the lessons.
#
# The play-first method increases confidence and connects theory, GenAI, and real-world
# application. It aligns with GenZ's preference for experiential learning, i.e., learning by doing.
# The readers will remember that this isn’t just another Python book. Instead, it is a unique
# journey where a fellow human and digital GenAI will accompany you every step. They will
# teach, demonstrate, guide, assist, and motivate as you learn Python coding. Furthermore, the
# readers can adapt the learning journey to various other college topics, including but not
# limited to science, history, art, and communication. Welcome to a learning experience
# tailored for our generation by one of our own.

# %% [markdown]
# # 🍎 Welcome to Chapter 5: Pandas, the Data Tamer
# ---

# %% [markdown]
# ## 🍀 Author: Duc
# ---
# ## Description:
#
# Welcome to a captivating chapter where we will harness the power of GPT-4 and Google Gemini (GenAI) latest AI marvel, to dive into the world of Python's Pandas library. This chapter is tailored for anyone eager to unlock the potential of data manipulation and analysis in Python, making it an invaluable resource whether you're a beginner or an experienced programmer looking to expand your skill set.
#
# The Pandas library is a cornerstone in Python programming, especially in data science. It offers robust, easy-to-use data structures and analysis tools, but its depth can be daunting. That's where GenAI comes in as your intelligent guide. With its advanced understanding and generation of human-like text, GenAI will help break down complex concepts, answer your questions, and even assist in writing and debugging code.
#
# Throughout this chapter, we'll explore the core functionalities of Pandas, from dataframes and series to intricate data manipulation techniques. You'll learn how to read, clean, and visualize data, all while GenAI provides tips, explanations, and code examples. By combining the interactive learning experience that GenAI offers with hands-on practice in Jupyter Notebooks, you're set to gain a comprehensive understanding of Pandas in an engaging and efficient way.
#
# So, gear up for an exciting journey into the world of Python's Pandas library with GenAI as your AI-powered mentor. Whether you aim to advance your career in data science or simply be passionate about data analytics, this chapter will equip you with the knowledge and skills you need to excel. Let's begin this journey of exploration and discovery together!
#
#
# ## Introduction:
#
# I consider Pandas a superhero library when managing data in Excel spreadsheets or relational database formats. It can simplify complex data cleaning, manipulation, and analysis tasks, which would otherwise be overwhelming. It seems like a magic wand that can transform scattered data into clear, useful information with just a few commands.
#
# GenAI has become my friendly guide in the world of data. It's like having a companion AI that helps me learn in a more approachable way. GenAI helps me understand complex concepts, answers numerous questions, and even provides code snippets to help me overcome roadblocks. It's like having a language tutor who's always there to assist me in finding the right words. GenAI has been an invaluable tool in my Pandas learning journey.
#
# Jupyter Notebook is an excellent environment for hands-on interaction with Pandas and GenAI. It's perfect for deep-diving into data wrangling, running real-time analyses, and getting immediate feedback.
#
#
# ##Topics to be covered:
# ---
#
# 1. Pandas Foundations
#
# 1. Manipulating Your Data
# 1. Data Analysis Superpowers
# 1. Diving Deeper Into Pandas
# 1. Charting Your Own Pandas Path

# %% [markdown]
# # 🤖 Topic #1: Pandas Foundations
#
# ---
#
# - Login GPT-4, https://chat.openai.com/
#
# - Open a "new chat" session
#
# - Start by asking "What is Python Pandas" from GPT-4. Here are some sample prompts to help you get started, but **highly encourage** you to write your prompts to express your idea of fun.
#
#   1. Explain what is Python Pandas in a knowleagable and conversation tone.
#
#   2. Explain Pandas in contrast to other main libraries such as Matplotlib and Numpy.
#
#   3. Give a few examples of other essential Pandas libraries.
#
#   4. Explain why Pandas are important for students to learn first.
#
#   5. What is the history of Python Pandas?
#
#   5. What are the key components of Pandas like dataframe?
#
#   5. Write a Python code example of creating a data frame of eight people with the name, age, height, and college major.
#
#   1. Show to code to sort df_people by age.
#     - Show me the Python code.
#
#   6. *(Your fun prompts goes here.)*
#
#   - Thought experiement: Can pandas Dataframe, cell contain another dataframe, and how deep can you go?

# %%
# prompt: Write a Python code example of creating a data frame of eight people with the name, age, height, and college major.

import pandas as pd

# Data for creating DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Hannah'],
    'Age': [22, 25, 24, 23, 22, 26, 21, 24],
    'Height': [165, 180, 175, 170, 169, 178, 160, 172],  # Assuming height in centimeters
    'College Major': ['Computer Science', 'Economics', 'Psychology', 'Mathematics', 'Biology', 'English', 'Physics', 'Art History']
}

# Creating DataFrame
df_people = pd.DataFrame(data)

# Display the DataFrame
# Note: remove "print" so it display as a nice table
df_people
# Out:
#       Name  Age  Height     College Major
# 0    Alice   22     165  Computer Science
# 1      Bob   25     180         Economics
# 2  Charlie   24     175        Psychology
# 3    David   23     170       Mathematics
# 4      Eva   22     169           Biology
# 5    Frank   26     178           English
# 6    Grace   21     160           Physics
# 7   Hannah   24     172       Art History

# %%
#prompt: Sort the df_peole based on the Age
#prompt: show me the code

# Sorting the DataFrame based on the 'Age' column
df_people_sorted = df_people.sort_values(by='Age')

# Display the sorted DataFrame
# remove the print() statement so it display nicer
df_people_sorted
# Out:
#       Name  Age  Height     College Major
# 6    Grace   21     160           Physics
# 0    Alice   22     165  Computer Science
# 4      Eva   22     169           Biology
# 3    David   23     170       Mathematics
# 7   Hannah   24     172       Art History
# 2  Charlie   24     175        Psychology
# 1      Bob   25     180         Economics
# 5    Frank   26     178           English

# %%
import numpy as np

# %% [markdown]
# ## Suggestion on the writing process
#
# ---
#
# - After you read all the answer from GPT-4 above:
#
#   - write about why you ask this question,
#
#   - what you exspect to read,
#   - how you feel about the answer
#   - summarize GPT-4 highlight/good point
#     - quote GPT-4 if you want to
#   - what surprise you about the answer.

# %% [markdown]
# # 🤖 Topic #2: Manipulating Your Data
#
# ---
#
# - Login GPT-4, https://chat.openai.com/
#
# - Use the same "Duc Chapter 5" GTP-4 session
#
# - Start by asking "What is Python Pandas" from GPT-4. Here are some sample prompts to help you get started, but **highly encourage** you to write your prompts to express your idea of fun.
#
#   1. What are the basic operation in Pandas DataFrame and give Python coding example.
#     - redo all the 10 coding example using df_people DataFrame.
#
#
#
#   6. *(Your fun prompts goes here.)*
#
#   - Thought experiement: Can pandas Dataframe, cell contain another dataframe, and how deep can you go?

# %%
# prompt: What are the basic operations in Pandas DataFrame? Then, give Python coding examples.

# 1. Creating a DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)

# Note: add in the output
df.head(4)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
# prompt: What are the basic operations in Pandas DataFrame? Then, give Python coding examples.

# 2. Selecting data: column
age_series = df['Age']
subset = df[['Name', 'Age']]

# Note: add the output
display(age_series)
display(subset)
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: Age, dtype: int64
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40

# %%
# prompt: What are the basic operations in Pandas DataFrame? Then, give Python coding examples.

# 2. Selecting data: row
df.head(2)
# Out:
#     Name  Age         City
# 0  Alice   25     New York
# 1    Bob   30  Los Angeles

# %%
# 1. Selecting a column
ages_series = df_people['Age']

# 2. Selecting multiple columns
name_and_major = df_people[['Name', 'College Major']]

# 3. Filtering rows
older_than_30 = df_people[df_people['Age'] > 30]

# 4. Adding a new column
df_people['Employed'] = np.random.choice([True, False], size=1000)

# 5. Dropping a column
df_people.drop('Employed', axis=1, inplace=True)

# 6. Renaming columns
df_people.rename(columns={'Age': 'Years'}, inplace=True)

# 7. Sorting data
sorted_by_age = df_people.sort_values(by='Years')

# 8. Basic statistics
statistics = df_people.describe()

# 9. Handling missing data
df_people['Salary'] = np.nan  # Adding a column with missing values
df_people_filled = df_people.fillna(value={'Salary': 50000})

# 10. Grouping and aggregating
average_age_by_major = df_people.groupby('College Major')['Years'].mean()

# 11. Merging and joining (creating another DataFrame for merging)
additional_data = pd.DataFrame({
    'Name': ['Person_0', 'Person_1'],
    'Salary': [70000, 80000]
})
merged_df = pd.merge(df_people, additional_data, on='Name', how='left')

# Display one of the operations for demonstration
print(sorted_by_age.head())

# %%
# prompt:
# prompt:

# Note: add import numpy:
import numpy as np

# 1. Selecting a column
ages_series = df_people['Age']

# 2. Selecting multiple columns
name_and_major = df_people[['Name', 'College Major']]

# 3. Filtering rows
older_than_30 = df_people[df_people['Age'] > 23]

# 4. Adding a new column
# prompt: there is an error in "df_people['Employed'] = np.random.choice([True, False], size=1000)" can you fix it?
# Note: new fixed code from GenAI
df_people['Employed'] = np.random.choice([True, False], size=len(df_people))
# Note: add output
print(f'\n{name_and_major}\n-----\n')
df_people

# 5. Dropping a column
df_people.drop('Employed', axis=1, inplace=True)

# 6. Renaming columns
df_people.rename(columns={'Age': 'Years'}, inplace=True)

# 7. Sorting data
sorted_by_age = df_people.sort_values(by='Years')

# 8. Basic statistics
statistics = df_people.describe()

# 9. Handling missing data
df_people['Salary'] = np.nan  # Adding a column with missing values
df_people_filled = df_people.fillna(value={'Salary': 50000})

# 10. Grouping and aggregating
average_age_by_major = df_people.groupby('College Major')['Years'].mean()

# 11. Merging and joining (creating another DataFrame for merging)
additional_data = pd.DataFrame({
    'Name': ['Person_0', 'Person_1'],
    'Salary': [70000, 80000]
})
merged_df = pd.merge(df_people, additional_data, on='Name', how='left')

# Display one of the operations for demonstration
print(sorted_by_age.head())

# %%
# 11. Merging and joining
additional_data = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Salary': [70000, 80000]
})
merged_df = pd.merge(df_people, additional_data, on='Name', how='left')
merged_df
# Out:
#       Name  Age  Height     College Major   Salary
# 0    Alice   22     165  Computer Science  70000.0
# 1      Bob   25     180         Economics  80000.0
# 2  Charlie   24     175        Psychology      NaN
# 3    David   23     170       Mathematics      NaN
# 4      Eva   22     169           Biology      NaN
# 5    Frank   26     178           English      NaN
# 6    Grace   21     160           Physics      NaN
# 7   Hannah   24     172       Art History      NaN

# %%
# prompt:
# prompt:

# Note: add import numpy:
import numpy as np

# 1. Selecting a column
ages_series = df_people['Age']
# Note: add output
print(f'\n 1. Selecting a column: \n-----\n')
display(ages_series)

# 2. Selecting multiple columns
name_and_major = df_people[['Name', 'College Major']]
# Note: add output
print(f'\n 2. Selecting multiple columns:\n-----\n')
display(name_and_major)

# 3. Filtering rows
older_than_22 = df_people[df_people['Age'] > 22]
# Note: add output
print(f'\n 3. Filtering rows:\n-----\n')
display(older_than_22)

# 4. Adding a new column
# Note: error because not import np (numpy)
# Note: original code:
# df_people['Employed'] = np.random.choice([True, False], size=1000)
#
# prompt: there is an error in "df_people['Employed'] = np.random.choice([True, False], size=1000)" can you fix it?
# Note: new fixed code from GenAI
df_people['Employed'] = np.random.choice([True, False], size=len(df_people))
# Note: add output
print(f'\n 4. Adding a new column:\n-----\n')
display(df_people)

# 5. Dropping a column
df_people.drop('Employed', axis=1, inplace=True)
# Note: add output
print(f'\n 5. Dropping a column:\n-----\n')
display(df_people)

# 6. Renaming columns
df_people.rename(columns={'Age': 'Years'}, inplace=True)
print(f'\n 6. Renaming columns:\n-----\n')
display(df_people)

# 7. Sorting data
sorted_by_age = df_people.sort_values(by='Years')
# Note: add output
print(f'\n 7. Sorting data:\n-----\n')
display(sorted_by_age)

# 8. Basic statistics
statistics = df_people.describe()
# Note: add output
print(f'\n 8. Basic statistics:\n-----\n')
display(statistics)

# 9. Handling missing data
df_people['Salary'] = np.nan  # Adding a column with missing values
df_people_filled = df_people.fillna(value={'Salary': 50000})
# Note: add output
print(f'\n 9. Handling missing data:\n-----\n')
display(df_people_filled)

# 10. Grouping and aggregating
average_age_by_major = df_people.groupby('College Major')['Years'].mean()
# Note: add output
print(f'\n 10. Grouping and aggregating:\n-----\n')
display(average_age_by_major)

# 11. Merging and joining (creating another DataFrame for merging)
additional_data = pd.DataFrame({
    'Name': ['Alice', 'Bob'],
    'Salary': [70000, 80000]
})
merged_df = pd.merge(df_people, additional_data, on='Name', how='left')
# Note: add output
print(f'\n 11. Merging and joining:\n-----\n')
display(merged_df)

# Display one of the operations for demonstration
# display(sorted_by_age.head())
# Out:
#  1. Selecting a column:
# -----
# 0    22
# 1    25
# 2    24
# 3    23
# 4    22
# 5    26
# 6    21
# 7    24
# Name: Age, dtype: int64
#  2. Selecting multiple columns:
# -----
#       Name     College Major
# 0    Alice  Computer Science
# 1      Bob         Economics
# 2  Charlie        Psychology
# 3    David       Mathematics
# 4      Eva           Biology
# 5    Frank           English
# 6    Grace           Physics
# 7   Hannah       Art History
#  3. Filtering rows:
# -----
#       Name  Age  Height College Major
# 1      Bob   25     180     Economics
# 2  Charlie   24     175    Psychology
# 3    David   23     170   Mathematics
# 5    Frank   26     178       English
# 7   Hannah   24     172   Art History
#  4. Adding a new column:
# -----
#       Name  Age  Height     College Major  Employed
# 0    Alice   22     165  Computer Science     False
# 1      Bob   25     180         Economics     False
# 2  Charlie   24     175        Psychology     False
# 3    David   23     170       Mathematics      True
# 4      Eva   22     169           Biology      True
# 5    Frank   26     178           English     False
# 6    Grace   21     160           Physics     False
# 7   Hannah   24     172       Art History     False
#  5. Dropping a column:
# -----
#       Name  Age  Height     College Major
# 0    Alice   22     165  Computer Science
# 1      Bob   25     180         Economics
# 2  Charlie   24     175        Psychology
# 3    David   23     170       Mathematics
# 4      Eva   22     169           Biology
# 5    Frank   26     178           English
# 6    Grace   21     160           Physics
# 7   Hannah   24     172       Art History
#  6. Renaming columns:
# -----
#       Name  Years  Height     College Major
# 0    Alice     22     165  Computer Science
# 1      Bob     25     180         Economics
# 2  Charlie     24     175        Psychology
# 3    David     23     170       Mathematics
# 4      Eva     22     169           Biology
# 5    Frank     26     178           English
# 6    Grace     21     160           Physics
# 7   Hannah     24     172       Art History
#  7. Sorting data:
# -----
#       Name  Years  Height     College Major
# 6    Grace     21     160           Physics
# 0    Alice     22     165  Computer Science
# 4      Eva     22     169           Biology
# 3    David     23     170       Mathematics
# 2  Charlie     24     175        Psychology
# 7   Hannah     24     172       Art History
# 1      Bob     25     180         Economics
# 5    Frank     26     178           English
#  8. Basic statistics:
# -----
#            Years      Height
# count   8.000000    8.000000
# mean   23.375000  171.125000
# std     1.685018    6.642665
# min    21.000000  160.000000
# 25%    22.000000  168.000000
# 50%    23.500000  171.000000
# 75%    24.250000  175.750000
# max    26.000000  180.000000
#  9. Handling missing data:
# -----
#       Name  Years  Height     College Major   Salary
# 0    Alice     22     165  Computer Science  50000.0
# 1      Bob     25     180         Economics  50000.0
# 2  Charlie     24     175        Psychology  50000.0
# 3    David     23     170       Mathematics  50000.0
# 4      Eva     22     169           Biology  50000.0
# 5    Frank     26     178           English  50000.0
# 6    Grace     21     160           Physics  50000.0
# 7   Hannah     24     172       Art History  50000.0
#  10. Grouping and aggregating:
# -----
# College Major
# Art History         24.0
# Biology             22.0
# Computer Science    22.0
# Economics           25.0
# English             26.0
# Mathematics         23.0
# Physics             21.0
# Psychology          24.0
# Name: Years, dtype: float64
#  11. Merging and joining:
# -----
#       Name  Years  Height     College Major  Salary_x  Salary_y
# 0    Alice     22     165  Computer Science       NaN   70000.0
# 1      Bob     25     180         Economics       NaN   80000.0
# 2  Charlie     24     175        Psychology       NaN       NaN
# 3    David     23     170       Mathematics       NaN       NaN
# 4      Eva     22     169           Biology       NaN       NaN
# 5    Frank     26     178           English       NaN       NaN
# 6    Grace     21     160           Physics       NaN       NaN
# 7   Hannah     24     172       Art History       NaN       NaN

# %%
# try out the boolean and logic operation
df_people[((df_people['Years'] >= 22) &
 (df_people['Years'] <= 25) & (df_people['Height'] > 166))]
# Out:
#       Name  Years  Height College Major  Salary
# 1      Bob     25     180     Economics     NaN
# 2  Charlie     24     175    Psychology     NaN
# 3    David     23     170   Mathematics     NaN
# 4      Eva     22     169       Biology     NaN
# 7   Hannah     24     172   Art History     NaN

# %%
import numpy as np

# %%
# prompt: there is an error in "df_people['Employed'] = np.random.choice([True, False], size=1000)" can you fix it?
# Note: new fixed code from GenAI

df_people['Employed'] = np.random.choice([True, False], size=len(df_people))

# Note: add output
display(df_people)
# Out:
#       Name  Age  Height     College Major  Employed
# 0    Alice   22     165  Computer Science      True
# 1      Bob   25     180         Economics     False
# 2  Charlie   24     175        Psychology     False
# 3    David   23     170       Mathematics      True
# 4      Eva   22     169           Biology      True
# 5    Frank   26     178           English      True
# 6    Grace   21     160           Physics      True
# 7   Hannah   24     172       Art History      True

# %%
# prompt:

import pandas as pd

# Extended player data including special abilities
player_data_with_abilities = {
    'Player Name': [
        'Eldor Windrunner', 'Mira Starlight', 'Thorn Underleaf',
        'Kaela Moonblade', 'Drex Stonefist', 'Luna Nightshade',
        'Orin Ironheart', 'Sylas Stormcaller', 'Jade Firehand', 'Zara Shadowend'
    ],
    'Class': [
        'Archer', 'Wizard', 'Rogue',
        'Ranger', 'Warrior', 'Assassin',
        'Paladin', 'Sorcerer', 'Mage', 'Necromancer'
    ],
    'Level': [5, 8, 3, 7, 10, 6, 4, 9, 2, 5],
    'Strength': [12, 8, 15, 14, 18, 13, 16, 9, 7, 10],
    'Dexterity': [18, 14, 20, 17, 12, 19, 11, 15, 13, 14],
    'Intelligence': [8, 17, 12, 10, 6, 15, 7, 18, 16, 20],
    'Health Points': [30, 24, 28, 35, 50, 32, 45, 22, 18, 26],
    'Mana Points': [10, 40, 15, 20, 5, 25, 30, 35, 45, 50],
    'Charisma': [12, 18, 11, 14, 10, 16, 13, 19, 17, 15],
    'Wisdom': [11, 16, 12, 13, 9, 15, 14, 20, 18, 17],
    'Perception': [14, 17, 19, 15, 12, 18, 13, 16, 20, 15],
    'Special Ability': [
        'Arrow Storm', 'Elemental Fury', 'Shadow Vanish',
        'Beast Call', 'Earthquake Punch', 'Fatal Strike',
        'Divine Shield', 'Chaos Bolt', 'Arcane Blast', 'Soul Drain'
    ]
}

# Creating the DataFrame
df_rpg_players_with_abilities = pd.DataFrame(player_data_with_abilities)

# Displaying the DataFrame
display(df_rpg_players_with_abilities)
# Out:
#          Player Name        Class  Level  Strength  Dexterity  Intelligence  \
# 0   Eldor Windrunner       Archer      5        12         18             8
# 1     Mira Starlight       Wizard      8         8         14            17
# 2    Thorn Underleaf        Rogue      3        15         20            12
# 3    Kaela Moonblade       Ranger      7        14         17            10
# 4     Drex Stonefist      Warrior     10        18         12             6
# 5    Luna Nightshade     Assassin      6        13         19            15
# 6     Orin Ironheart      Paladin      4        16         11             7
# 7  Sylas Stormcaller     Sorcerer      9         9         15            18
# 8      Jade Firehand         Mage      2         7         13            16
# 9     Zara Shadowend  Necromancer      5        10         14            20
#
#    Health Points  Mana Points  Charisma  Wisdom  Perception   Special Ability
# 0             30           10        12      11          14       Arrow Storm
# 1             24           40        18      16          17    Elemental Fury
# 2             28           15        11      12          19     Shadow Vanish
# 3             35           20        14      13          15        Beast Call
# 4             50            5        10       9          12  Earthquake Punch
# 5             32           25        16      15          18      Fatal Strike
# 6             45           30        13      14          13     Divine Shield
# 7             22           35        19      20          16        Chaos Bolt
# 8             18           45        17      18          20      Arcane Blast
# 9             26           50        15      17          15        Soul Drain

# %%
df_people[df_people['Age'] > 22]

# %% [markdown]
# #### 🐣 Fun Fact:
# ---
# The below code is written entirely by GenAI with just the prompt:

# %% [markdown]
# # 🤖 Topic #3: Data Analysis Superpowers
#
# ---
#
# - a

# %%
# prompt: import the following link into DataFrame: https://raw.githubusercontent.com/duchaba/book_python_genAI_genZ/blob/master/global_warming_trends/long_format_annual_surface_temp.csv

import pandas as pd

# Read the CSV file into a Pandas DataFrame
fname = 'https://raw.githubusercontent.com/duchaba/book_python_genAI_genZ/master/global_warming_trends/long_format_annual_surface_temp.csv'
df_global_warming = pd.read_csv(fname)

# Display the DataFrame
df_global_warming.head()
# Out:
#                         Country ISO2   Year  Temperature
# 0  Afghanistan, Islamic Rep. of   AF  F1961       -0.113
# 1                       Albania   AL  F1961        0.627
# 2                       Algeria   DZ  F1961        0.164
# 3                American Samoa   AS  F1961        0.079
# 4      Andorra, Principality of   AD  F1961        0.736

# %%
# prompt: display information about df_global_warming

df_global_warming.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11222 entries, 0 to 11221
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      11222 non-null  object
#  1   ISO2         11222 non-null  object
#  2   Year         11222 non-null  object
#  3   Temperature  11222 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 350.8+ KB

# %%
# prompt: remove the leading "F" in the Year column in df_global_warming

df_global_warming['Year'] = df_global_warming['Year'].str[1:]
df_global_warming.head()
# Out:
#                         Country ISO2  Year  Temperature
# 0  Afghanistan, Islamic Rep. of   AF  1961       -0.113
# 1                       Albania   AL  1961        0.627
# 2                       Algeria   DZ  1961        0.164
# 3                American Samoa   AS  1961        0.079
# 4      Andorra, Principality of   AD  1961        0.736

# %%
# prompt: convert the year column in df_global_warming into an integer

df_global_warming['Year'] = df_global_warming['Year'].astype('int64')
df_global_warming.head()
# Out:
#                         Country ISO2  Year  Temperature
# 0  Afghanistan, Islamic Rep. of   AF  1961       -0.113
# 1                       Albania   AL  1961        0.627
# 2                       Algeria   DZ  1961        0.164
# 3                American Samoa   AS  1961        0.079
# 4      Andorra, Principality of   AD  1961        0.736

# %%
# prompt: plot a line graph the temperature of for the year 1961 and the year 2022 for each ISO2 from df_global_warming

df_1961 = df_global_warming[df_global_warming['Year'] == 1961]
df_2022 = df_global_warming[df_global_warming['Year'] == 2022]

import matplotlib.pyplot as plt

plt.plot(df_1961['ISO2'], df_1961['Temperature'])
plt.plot(df_2022['ISO2'], df_2022['Temperature'])

plt.xlabel('ISO2')
plt.ylabel('Average Yearly Temperature (C)')
plt.title('Temperature for 1961 and 2022')
plt.legend(['1961', '2022'])
plt.show()

# %%
# prompt: plot a line graph the temperature for ISO2 is US for each year from df_global_warming

df_us = df_global_warming[df_global_warming['ISO2'] == 'US']
plt.plot(df_us['Year'], df_us['Temperature'])
plt.xlabel('Year')
plt.ylabel('Average Yearly Temperature (C)')
plt.title('Temperature for the US from 1961 to 2022')
plt.show()

# %%
# prompt: plot a area graph the temperature for ISO2 is US for each year from df_global_warming

df_us = df_global_warming[df_global_warming['ISO2'] == 'US']
plt.plot(df_us['Year'], df_us['Temperature'])
plt.fill_between(df_us['Year'], df_us['Temperature'], alpha=0.2)
plt.xlabel('Year')
plt.ylabel('Average Yearly Temperature (C)')
plt.title('Temperature for the US from 1961 to 2022')
plt.show()

# %%
# prompt: create a new dataframe from df_global_warming where average temperature group by ISO2

df_global_warming_grouped = df_global_warming.groupby('ISO2')['Temperature'].mean().reset_index()
df_global_warming_grouped.head()
# Out:
#   ISO2  Temperature
# 0   AD     0.792806
# 1   AE     0.425887
# 2   AF     0.484661
# 3   AG     0.396694
# 4   AI     0.404210

# %%
df_global_warming_grouped = df_global_warming.groupby('Country')['Temperature'].mean().reset_index()
df_global_warming_grouped.head()
# Out:
#                         Country  Temperature
# 0  Afghanistan, Islamic Rep. of     0.484661
# 1                       Albania     0.471387
# 2                       Algeria     0.724871
# 3                American Samoa     0.521290
# 4      Andorra, Principality of     0.792806

# %%
# prompt: sort df_global_warming_grouped by temperature

df_global_warming_grouped.sort_values(by='Temperature', inplace=True)
df_global_warming_grouped.head()
# Out:
#                        Country  Temperature
# 40                Cook Islands     0.139435
# 180                   Zimbabwe     0.203677
# 137  Saint Pierre and Miquelon     0.213387
# 19                    Botswana     0.220129
# 115                      Nepal     0.232016

# %%
# prompt: plot an area graph for temperature for first 20 record in df_global_warming_grouped and the x-axis is Country

df_global_warming_grouped.head(20).plot.area(x='Country', y='Temperature')
plt.xlabel('Country')
plt.ylabel('Average Yearly Temperature (C)')
plt.title('Temperature for the first 20 countries')
plt.show()

# %%
# prompt: change figsize to 16,5

df_global_warming_grouped.head(20).plot.area(x='Country', y='Temperature', figsize=(16, 5))
plt.xlabel('Country')
plt.ylabel('Average Yearly Temperature (C)')
plt.title('Temperature for the first 20 countries')
plt.show()

# %%
df_global_warming_grouped.head(20)
# Out:
#                        Country  Temperature
# 40                Cook Islands     0.139435
# 180                   Zimbabwe     0.203677
# 137  Saint Pierre and Miquelon     0.213387
# 19                    Botswana     0.220129
# 115                      Nepal     0.232016
# 13                  Bangladesh     0.232629
# 32                       Chile     0.265129
# 37       Comoros, Union of the     0.268677
# 125                   Pakistan     0.290694
# 122             Norfolk Island     0.293968
# 75                       India     0.298694
# 118                New Zealand     0.303597
# 124                       Oman     0.306323
# 106                    Mayotte     0.309210
# 87                    Kiribati     0.324548
# 8                    Argentina     0.329726
# 176         West Bank and Gaza     0.333419
# 81                      Israel     0.333516
# 127           Papua New Guinea     0.343242
# 165                     Tuvalu     0.344048

# %%
# prompt: plot an area graph for temperature for last 20 record in df_global_warming_grouped and the x-axis is Country

df_global_warming_grouped.tail(20).plot.area(x='Country', y='Temperature', figsize=(16, 5))
plt.xlabel('Country')
plt.ylabel('Average Yearly Temperature (C)')
plt.title('Temperature for the last 20 countries')
plt.show()

# %%
df_global_warming_grouped.tail(20)
# Out:
#                          Country  Temperature
# 136                 Saint Helena     0.732032
# 12           Bahrain, Kingdom of     0.737565
# 116             Netherlands, The     0.741177
# 55                        France     0.747758
# 153                       Sweden     0.752726
# 111                      Morocco     0.758339
# 163                      Tunisia     0.759048
# 59                       Germany     0.767484
# 90                        Kuwait     0.772952
# 58                   Gambia, The     0.773177
# 141                      Senegal     0.784145
# 154                  Switzerland     0.786065
# 96                 Liechtenstein     0.789871
# 4       Andorra, Principality of     0.792806
# 54                       Finland     0.793726
# 25                    Cabo Verde     0.797177
# 177               Western Sahara     0.805548
# 10                       Austria     0.809371
# 104  Mauritania, Islamic Rep. of     0.893597
# 109                     Mongolia     0.895597

# %%
# prompt: prompt: create a new dataframe from df_global_warming where average temperature group by year

df_global_warming_by_year = df_global_warming.groupby('Year')['Temperature'].mean().reset_index()
df_global_warming_by_year.head()
# Out:
#    Year  Temperature
# 0  1961     0.168829
# 1  1962    -0.010934
# 2  1963    -0.001066
# 3  1964    -0.070768
# 4  1965    -0.247564

# %%
# prompt: plot bar graph the temperature for Year from df_global_warming_by_year

df_global_warming_by_year.plot.bar(x='Year', y='Temperature', figsize=(16, 4))
plt.title('Average Global Temperature by Year')
plt.xlabel('Year')
plt.ylabel('Average Temperature (C)')
plt.show()

# %%
# prompt: create a new dataframe from df_global_warming_by_year where the Temperature is increasing by 1.0

df_global_warming_by_year_increased = df_global_warming_by_year.copy()
df_global_warming_by_year_increased['Temperature'] += 1.0
df_global_warming_by_year_increased.head()
# Out:
#    Year  Temperature
# 0  1961     1.168829
# 1  1962     0.989066
# 2  1963     0.998934
# 3  1964     0.929232
# 4  1965     0.752436

# %%
# prompt: plot bar graph the temperature for Year from df_global_warming_by_year_increased use color orange

df_global_warming_by_year_increased.plot.bar(x='Year', y='Temperature', figsize=(16, 4), color='orange')
plt.title('Average Global Temperature by Year (Increased by 1 Degree Celsius)')
plt.xlabel('Year')
plt.ylabel('Average Temperature (C)')
plt.show()

# %%
# prompt: plot bar graph the temperature for Year from df_global_warming_by_year and df_global_warming_by_year_increased combine into one graph

df_combined = pd.merge(df_global_warming_by_year, df_global_warming_by_year_increased, on='Year')
df_combined.columns = ['Year', 'Temperature', 'Temperature_Increased']

# Plot the combined bar graph
df_combined.plot.bar(x='Year', y=['Temperature', 'Temperature_Increased'], figsize=(16, 4))
plt.title('Average Global Temperature by Year (Original and Increased)')
plt.xlabel('Year')
plt.ylabel('Average Temperature (C)')
plt.show()

# %% [markdown]
# #### 🐣 Fun Fact:
# ---
# The below code is written entirely by GenAI with just the prompt:

# %% [markdown]
# # 🤖 Topic #4: Diving Deeper Into Pandas
#
# ---
#
# - a
#
#   4. *(Your prompt goes here.)*

# %% [markdown]
# # 🤖 Topic #5:
# ---
#
# - a
#
#   4. *(Your prompt goes here.)*

# %% [markdown]
# # 🍵 Conclusion
#
# ---
#
# - Summarize what we have done in this chapter.
#
# - Write your thoughts about chapter 5.
#
# - Memtion the next chapter, chapter 6 is about CNN, and the author is Duc.

# %%
print("end of chapter 5.")
# Out:
# end of chapter 5.
